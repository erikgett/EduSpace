# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Генерируем данные

# %% [markdown]
# Есть много способов найти и удалить выбросы:
# * https://www.kaggle.com/datasets/dileep070/heart-disease-prediction-using-logistic-regression
# * Усечение данных на основе некоторого порогового значения
# * Усечение на основе IQR (interquantile range - межквантильный размах) или STD (standard deviation - среднеквадратическое отклонение)
# * https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba
# * https://towardsdatascience.com/5-ways-to-detect-outliers-that-every-data-scientist-should-know-python-code-70a54335a623

# %% [markdown]
# ## Набор данных "Logistic regression To predict heart disease"

# %% [markdown]
# About Dataset
# LOGISTIC REGRESSION - HEART DISEASE PREDICTION
#
# Introduction
# World Health Organization has estimated 12 million deaths occur worldwide, every year due to Heart diseases. Half the deaths in the United States and other developed countries are due to cardio vascular diseases. The early prognosis of cardiovascular diseases can aid in making decisions on lifestyle changes in high risk patients and in turn reduce the complications. This research intends to pinpoint the most relevant/risk factors of heart disease as well as predict the overall risk using logistic regression
# Data Preparation
#
# Source
# The dataset is publically available on the Kaggle website, and it is from an ongoing cardiovascular study on residents of the town of Framingham, Massachusetts. The classification goal is to predict whether the patient has 10-year risk of future coronary heart disease (CHD).The dataset provides the patients’ information. It includes over 4,000 records and 15 attributes.
# Variables
# Each attribute is a potential risk factor. There are both demographic, behavioral and medical risk factors.
#
# Demographic:
# • Sex: male or female(Nominal)
# • Age: Age of the patient;(Continuous - Although the recorded ages have been truncated to whole numbers, the concept of age is continuous)
# Behavioral
# • Current Smoker: whether or not the patient is a current smoker (Nominal)
# • Cigs Per Day: the number of cigarettes that the person smoked on average in one day.(can be considered continuous as one can have any number of cigarettes, even half a cigarette.)
# Medical( history)
# • BP Meds: whether or not the patient was on blood pressure medication (Nominal)
# • Prevalent Stroke: whether or not the patient had previously had a stroke (Nominal)
# • Prevalent Hyp: whether or not the patient was hypertensive (Nominal)
# • Diabetes: whether or not the patient had diabetes (Nominal)
# Medical(current)
# • Tot Chol: total cholesterol level (Continuous)
# • Sys BP: systolic blood pressure (Continuous)
# • Dia BP: diastolic blood pressure (Continuous)
# • BMI: Body Mass Index (Continuous)
# • Heart Rate: heart rate (Continuous - In medical research, variables such as heart rate though in fact discrete, yet are considered continuous because of large number of possible values.)
# • Glucose: glucose level (Continuous)
# Predict variable (desired target)
# • 10 year risk of coronary heart disease CHD (binary: “1”, means “Yes”, “0” means “No”)
# Logistic Regression
# Logistic regression is a type of regression analysis in statistics used for prediction of outcome of a categorical dependent variable from a set of predictor or independent variables. In logistic regression the dependent variable is always binary. Logistic regression is mainly used to for prediction and also calculating the probability of success.
# The results above show some of the attributes with P value higher than the preferred alpha(5%) and thereby showing low statistically significant relationship with the probability of heart disease. Backward elimination approach is used here to remove those attributes with highest P-value one at a time followed by running the regression repeatedly until all attributes have P Values less than 0.05.
# Feature Selection: Backward elimination (P-value approach)
# Logistic regression equation
# P=eβ0+β1X1/1+eβ0+β1X1P=eβ0+β1X1/1+eβ0+β1X1
# When all features plugged in:
# logit(p)=log(p/(1−p))=β0+β1∗Sexmale+β2∗age+β3∗cigsPerDay+β4∗totChol+β5∗sysBP+β6∗glucoselogit(p)=log(p/(1−p))=β0+β1∗Sexmale+β2∗age+β3∗cigsPerDay+β4∗totChol+β5∗sysBP+β6∗glucose
#
# Interpreting the results: Odds Ratio, Confidence Intervals and P-values
# • This fitted model shows that, holding all other features constant, the odds of getting diagnosed with heart disease for males (sex_male = 1)over that of females (sex_male = 0) is exp(0.5815) = 1.788687. In terms of percent change, we can say that the odds for males are 78.8% higher than the odds for females.
# • The coefficient for age says that, holding all others constant, we will see 7% increase in the odds of getting diagnosed with CDH for a one year increase in age since exp(0.0655) = 1.067644.
# • Similarly , with every extra cigarette one smokes thers is a 2% increase in the odds of CDH.
# • For Total cholesterol level and glucose level there is no significant change.
#
# • There is a 1.7% increase in odds for every unit increase in systolic Blood Pressure.
#
# Model Evaluation - Statistics
# From the above statistics it is clear that the model is highly specific than sensitive. The negative values are predicted more accurately than the positives.
# Predicted probabilities of 0 (No Coronary Heart Disease) and 1 ( Coronary Heart Disease: Yes) for the test data with a default classification threshold of 0.5
# lower the threshold
# Since the model is predicting Heart disease too many type II errors is not advisable. A False Negative ( ignoring the probability of disease when there actually is one) is more dangerous than a False Positive in this case. Hence in order to increase the sensitivity, threshold can be lowered.
#
# Conclusions
# • All attributes selected after the elimination process show P-values lower than 5% and thereby suggesting significant role in the Heart disease prediction.
#
# • Men seem to be more susceptible to heart disease than women. Increase in age, number of cigarettes smoked per day and systolic Blood Pressure also show increasing odds of having heart disease
#
# • Total cholesterol shows no significant change in the odds of CHD. This could be due to the presence of 'good cholesterol(HDL) in the total cholesterol reading. Glucose too causes a very negligible change in odds (0.2%)
#
# • The model predicted with 0.88 accuracy. The model is more specific than sensitive. Overall model could be improved with more data
#
# Appendix
# http://www.who.int/mediacentre/factsheets/fs317/en/
# Data Source References
# https://www.kaggle.com/amanajmera1/framingham-heart-study-dataset/data

# %% [markdown]
# Этот более данные о пациентов умерших от сердечно-сосудистых заболеваний.
#
# Это набор подойдет для сохдания моделей регрессии.

# %% [markdown]
# Demographic:
#
# • Sex: male or female(Nominal)
# • Пол: мужской или женский (номинальный)
#
# • Age: Age of the patient;(Continuous - Although the recorded ages have been truncated to whole numbers, the concept of age is continuous)
# • Возраст: возраст пациента; (непрерывный — хотя записанный возраст был усечен до целых чисел, понятие возраста является непрерывным)
#
# Behavioral:
#
# • Current Smoker: whether or not the patient is a current smoker (Nominal)
# • Текущий курильщик: является ли пациент курильщиком в настоящее время (номинальное значение).
#
# • Cigs Per Day: the number of cigarettes that the person smoked on average in one day.(can be considered continuous as one can have any number of cigarettes, even half a cigarette.)
# • Сигарет в день: количество сигарет, выкуриваемых человеком в среднем за один день (может считаться непрерывным, поскольку человек может выкуривать любое количество сигарет, даже половину сигареты).
#
# Medical( history):
#
# • BP Meds: whether or not the patient was on blood pressure medication (Nominal)
# • BP Meds: принимал ли пациент лекарства от артериального давления (номинальное значение).
#
# • Prevalent Stroke: whether or not the patient had previously had a stroke (Nominal)
# • Распространенный инсульт: был ли у пациента ранее инсульт (номинальное значение).
#
# • Prevalent Hyp: whether or not the patient was hypertensive (Nominal)
# • Распространенный Hyp: был ли пациент гипертоником (номинальное значение)
#
# • Diabetes: whether or not the patient had diabetes (Nominal)
# Medical(current)
# • Диабет: был ли у пациента диабет (номинальное значение)
# Медицинский (текущий)
#
# • Tot Chol: total cholesterol level (Continuous)
# • Tot Chol: общий уровень холестерина (непрерывно)
#
# • Sys BP: systolic blood pressure (Continuous)
# • Sys BP: систолическое артериальное давление (непрерывно)
#
# • Dia BP: diastolic blood pressure (Continuous)
# • Dia BP: диастолическое артериальное давление (непрерывно)
#
# • BMI: Body Mass Index (Continuous)
# • ИМТ: индекс массы тела (непрерывный)
#
# • Heart Rate: heart rate (Continuous - In medical research, variables such as heart rate though in fact discrete, yet are considered continuous because of large number of possible values.)
# • Частота сердечных сокращений: частота сердечных сокращений (непрерывная — в медицинских исследованиях такие переменные, как частота сердечных сокращений, хотя на самом деле являются дискретными, но считаются непрерывными из-за большого количества возможных значений).
#
# • Glucose: glucose level (Continuous)
# Predict variable (desired target)
# • Глюкоза: уровень глюкозы (непрерывно)
# Предсказать переменную (желаемую цель)
#
# • 10 year risk of coronary heart disease CHD (binary: “1”, means “Yes”, “0” means “No”)
# • 10-летний риск ишемической болезни сердца ИБС (двоичный код: «1» означает «Да», «0» означает «Нет»)
# Демография:

# %%
df = pd.read_csv("framingham.csv")

# %%
df.corr()
# Out:
#                      male       age  education  currentSmoker  cigsPerDay  \
# male             1.000000 -0.028979   0.017352       0.197596    0.317930
# age             -0.028979  1.000000  -0.165883      -0.213748   -0.192791
# education        0.017352 -0.165883   1.000000       0.018532    0.008085
# currentSmoker    0.197596 -0.213748   0.018532       1.000000    0.769690
# cigsPerDay       0.317930 -0.192791   0.008085       0.769690    1.000000
# BPMeds          -0.052506  0.122995  -0.010815      -0.048938   -0.046134
# prevalentStroke -0.004546  0.057655  -0.035112      -0.032988   -0.032707
# prevalentHyp     0.005313  0.307194  -0.081970      -0.103260   -0.066146
# diabetes         0.015708  0.101258  -0.038680      -0.044295   -0.037067
# totChol         -0.070322  0.262131  -0.023115      -0.046562   -0.026320
# sysBP           -0.035989  0.394302  -0.129631      -0.130230   -0.088780
# diaBP            0.057933  0.206104  -0.062316      -0.107746   -0.056632
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot: >

# %%
df.corr()['sysBP'].sort_values()
# Out:
# currentSmoker     -0.130230
# education         -0.129631
# cigsPerDay        -0.088780
# male              -0.035989
# prevalentStroke    0.057009
# diabetes           0.111283
# glucose            0.140621
# heartRate          0.182246
# totChol            0.208908
# TenYearCHD         0.216429
# BPMeds             0.254219
# BMI                0.326981
# age                0.394302
# prevalentHyp       0.696755
# diaBP              0.784002
# sysBP              1.000000
# Name: sysBP, dtype: float64

# %%
#sns.distplot(df["Depth Seismic Stations"])

# %%
sns.scatterplot(x='sysBP', y='diaBP', data=df)
# Out:
# <AxesSubplot: xlabel='sysBP', ylabel='diaBP'>

# %%
df[(df['sysBP']>220) & (df['diaBP']>100)]
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 481      0   64        1.0              0         0.0     0.0
# 864      0   59        2.0              0         0.0     1.0
# 1189     0   48        1.0              0         0.0     0.0
# 1989     1   61        1.0              0         0.0     0.0
# 3489     0   62        2.0              0         0.0     1.0
# 3616     0   54        2.0              1        15.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 481                 0             1         0    253.0  295.0  135.0  38.82
# 864                 0             1         0    264.0  244.0  124.0  19.61
# 1189                0             1         0    169.0  243.0  142.5  28.49
# 1989                0             1         0    238.0  232.0  136.0  24.83
# 3489                0             1         0    298.0  248.0  130.0  37.10
# ...

# %%
sns.scatterplot(x='sysBP', y='prevalentHyp', data=df)
# Out:
# <AxesSubplot: xlabel='sysBP', ylabel='prevalentHyp'>

# %%
df[(df['sysBP']>220) & (df['prevalentHyp']>0)]
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 481      0   64        1.0              0         0.0     0.0
# 864      0   59        2.0              0         0.0     1.0
# 1189     0   48        1.0              0         0.0     0.0
# 1989     1   61        1.0              0         0.0     0.0
# 2091     1   65        1.0              0         0.0     0.0
# 3489     0   62        2.0              0         0.0     1.0
# 3616     0   54        2.0              1        15.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 481                 0             1         0    253.0  295.0  135.0  38.82
# 864                 0             1         0    264.0  244.0  124.0  19.61
# 1189                0             1         0    169.0  243.0  142.5  28.49
# 1989                0             1         0    238.0  232.0  136.0  24.83
# 2091                0             1         1    240.0  235.0  100.0    NaN
# ...

# %%
df[(df['sysBP']>220) & (df['diaBP']>100)].index
# Out:
# Int64Index([481, 864, 1189, 1989, 3489, 3616], dtype='int64')

# %%
ind_drop = df[(df['sysBP']>220) & (df['diaBP']>100)].index

# %%
df = df.drop(ind_drop,axis=0)

# %%
sns.scatterplot(x='sysBP', y='diaBP', data=df)
# Out:
# <AxesSubplot: xlabel='sysBP', ylabel='diaBP'>

# %%
sns.scatterplot(x='sysBP', y='prevalentHyp', data=df)
# Out:
# <AxesSubplot: xlabel='sysBP', ylabel='prevalentHyp'>

# %% [markdown]
# ##Работа с отсутствующими данными (пропущенными данными, Missing Data)

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4232 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4232 non-null   int64
#  1   age              4232 non-null   int64
#  2   education        4127 non-null   float64
#  3   currentSmoker    4232 non-null   int64
#  4   cigsPerDay       4203 non-null   float64
#  5   BPMeds           4179 non-null   float64
#  6   prevalentStroke  4232 non-null   int64
#  7   prevalentHyp     4232 non-null   int64
#  8   diabetes         4232 non-null   int64
#  9   totChol          4182 non-null   float64
#  10  sysBP            4232 non-null   float64
#  11  diaBP            4232 non-null   float64
#  12  BMI              4213 non-null   float64
#  13  heartRate        4231 non-null   float64
#  14  glucose          3844 non-null   float64
#  15  TenYearCHD       4232 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %% [markdown]
# В данном наборе в некоторых столбцах замечены пропущенные значения, отмеченные нулем.

# %%
def percent_missing(df):
    percent_nan = 100* df.isnull().sum() / len(df)
    percent_nan = percent_nan[percent_nan>0].sort_values()
    return percent_nan

# %%
fig, ax = plt.subplots()
percent_nan = percent_missing(df)
sns.barplot(x=percent_nan.index,y=percent_nan)

plt.xticks(rotation=90)
plt.show()

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df[df['BMI'].isnull()]
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 97       0   40        2.0              0         0.0     0.0
# 294      0   47        1.0              1        25.0     0.0
# 705      0   45        3.0              0         0.0     0.0
# 1155     0   64        2.0              1         3.0     0.0
# 1161     0   47        2.0              0         0.0     0.0
# 1594     0   40        2.0              0         0.0     0.0
# 1604     1   40        NaN              1        20.0     0.0
# 1624     0   70        1.0              0         0.0     0.0
# 1747     0   51        1.0              0         0.0     0.0
# 1975     1   63        1.0              1        20.0     0.0
# 2048     0   35        2.0              0         0.0     0.0
# 2067     0   58        1.0              1         1.0     0.0
# 2091     1   65        1.0              0         0.0     0.0
# 2177     0   53        3.0              0         0.0     0.0
# ...

# %%
df[df['heartRate'].isnull()]
# Out:
#      male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 689     1   64        1.0              1        18.0     0.0                0
#
#      prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 689             1         0    219.0  172.5   75.0  29.29        NaN     91.0
#
#      TenYearCHD
# 689           1

# %%
df[df['education'].isnull()]
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 33       1   61        NaN              1         5.0     0.0
# 36       1   56        NaN              0         0.0     0.0
# 72       0   37        NaN              0         0.0     0.0
# 184      1   67        NaN              0         0.0     0.0
# 213      0   34        NaN              0         0.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4082     1   47        NaN              0         0.0     0.0
# 4098     1   37        NaN              1        20.0     0.0
# 4121     0   55        NaN              0         0.0     0.0
# 4122     1   69        NaN              1        23.0     0.0
# 4138     1   67        NaN              1        25.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 33                  0             0         0    175.0  134.0   82.5  18.59
# ...

# %%
df[df['cigsPerDay'].isnull()]
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 131      1   43        4.0              1         NaN     0.0
# 139      1   49        4.0              1         NaN     0.0
# 1046     0   49        1.0              1         NaN     0.0
# 1292     1   42        3.0              1         NaN     0.0
# 1347     0   58        4.0              1         NaN     0.0
# 1451     1   54        1.0              1         NaN     0.0
# 1497     1   55        1.0              1         NaN     0.0
# 1610     0   61        1.0              1         NaN     0.0
# 1625     0   49        2.0              1         NaN     0.0
# 1870     0   47        2.0              1         NaN     0.0
# 1963     1   45        3.0              1         NaN     0.0
# 1980     0   60        2.0              1         NaN     0.0
# 2405     0   49        1.0              1         NaN     0.0
# 2513     1   42        1.0              1         NaN     0.0
# ...

# %% [markdown]
# # Удаление признаков или удаление строк
#
# Если значения отсутствуют только в нескольких строках, количество которых мало по сравнению с общим количеством строк, то можно рассмотреть вариант удалить такие строки. К чему это приведёт с точки зрения точности работы модели? По сути, мы удаляем некоторые данные для обучения и тестирования, но поскольку таких строк очень мало, то скорее всего мы не сильно повлияем на точность модели.
#
# Если же значения отсутствуют почти во всех строках, то имеет смысл полностью удалить такие признаки. Однако перед этим следует внимательно разобраться, почему неопределённых значений так много. В некоторых случаях можно рассмотреть такие данные как отдельную категорию, отдельно от остальных данных.
#
# В качестве примера возьмём признак "количество машин, которые могут поместиться в гараже". Но если гаража вообще нет, то вместо значения 0 может проставляться неопределённое значение null. В таким случае имеет смысл заменить значения null на нули. Только Вы можете решить, что делать с неопределёнными значениями! Используйте Ваши знания о предметной области и специфике данных!

# %% [markdown]
# ## Работа с отсутствующими данными в строках
#
# ## Заменять данные чем-то, или удалять данные?
#
# Давайте поймём, в каких случаях лучше заменять отсутствующие данные какими-то значениями (например, средним значением), а в каких случаях удалять такие строки. Давайте выберем некоторое пороговое значение (threshold) и договоримся, что при его привышении мы решаем удалять строки (вместо того, чтобы заменять отсутствующее значение каким-то другим значением). Мы выберем пороговое значение 1%. Это значит, что если меньше 1% строк содержат неопределённое значение какого-то признака, то мы просто удалим такие строки. Здесь нет правильного ответа на вопрос, какое следует выбрать пороговое значение. Можете использовать знания о специфике предметной области, но в любом случае пороговое значение не должно быть очень большим, например 50%.
#
# Глядя на текстовое описание признаков, мы видим, что в нашем случае значения NaN проставляются намеренно - они означают 0 или "нисколько".

# %%
df = df.dropna(subset=['heartRate'])

# %%
df = df.dropna(subset=['BMI'])
df = df.dropna(subset=['cigsPerDay'])

# %%
fig, ax = plt.subplots()
percent_nan = percent_missing(df)
sns.barplot(x=percent_nan.index,y=percent_nan)

plt.xticks(rotation=90)
plt.show()

# %%
df.isnull().sum()[df.isnull().sum()>0].sort_values(ascending = False)
# Out:
# glucose      379
# education    102
# BPMeds        53
# totChol       49
# dtype: int64

# %%
df['education'].fillna(df['education'].mean())
# Out:
# 0       4.0
# 1       2.0
# 2       1.0
# 3       3.0
# 4       3.0
#        ...
# 4233    1.0
# 4234    3.0
# 4235    2.0
# 4236    1.0
# 4237    2.0
# Name: education, Length: 4183, dtype: float64

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df[df['education'].isnull()]
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 33       1   61        NaN              1         5.0     0.0
# 36       1   56        NaN              0         0.0     0.0
# 72       0   37        NaN              0         0.0     0.0
# 184      1   67        NaN              0         0.0     0.0
# 213      0   34        NaN              0         0.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4082     1   47        NaN              0         0.0     0.0
# 4098     1   37        NaN              1        20.0     0.0
# 4121     0   55        NaN              0         0.0     0.0
# 4122     1   69        NaN              1        23.0     0.0
# 4138     1   67        NaN              1        25.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 33                  0             0         0    175.0  134.0   82.5  18.59
# ...

# %%
df['education'] = df['education'].fillna(df['education'].mean())

# %%
df.isnull().sum()[df.isnull().sum()>0].sort_values(ascending = False)
# Out:
# glucose    379
# BPMeds      53
# totChol     49
# dtype: int64

# %%
df['totChol'] = df['totChol'].fillna(df['totChol'].mean())
df['BPMeds'] = df['BPMeds'].fillna(df['BPMeds'].mean())

# %%
df['glucose']=df['glucose'].fillna(df['glucose'].median())

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay    BPMeds  \
# 0        1   39        4.0              0         0.0  0.000000
# 1        0   46        2.0              0         0.0  0.000000
# 2        1   48        1.0              1        20.0  0.000000
# 3        0   61        3.0              1        30.0  0.000000
# 4        0   46        3.0              1        23.0  0.000000
# ...    ...  ...        ...            ...         ...       ...
# 4233     1   50        1.0              1         1.0  0.000000
# 4234     1   51        3.0              1        43.0  0.000000
# 4235     0   48        2.0              1        20.0  0.029298
# 4236     0   44        1.0              1        15.0  0.000000
# 4237     0   52        2.0              0         0.0  0.000000
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4183 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4183 non-null   int64
#  1   age              4183 non-null   int64
#  2   education        4183 non-null   float64
#  3   currentSmoker    4183 non-null   int64
#  4   cigsPerDay       4183 non-null   float64
#  5   BPMeds           4183 non-null   float64
#  6   prevalentStroke  4183 non-null   int64
#  7   prevalentHyp     4183 non-null   int64
#  8   diabetes         4183 non-null   int64
#  9   totChol          4183 non-null   float64
#  10  sysBP            4183 non-null   float64
#  11  diaBP            4183 non-null   float64
#  12  BMI              4183 non-null   float64
#  13  heartRate        4183 non-null   float64
#  14  glucose          4183 non-null   float64
#  15  TenYearCHD       4183 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
df['male'] = df['male'].astype(bool)
df['education'] = df['education'].astype(int)
df['education'] = df['education'].astype(int)
df['currentSmoker'] = df['currentSmoker'].astype(bool)
df['cigsPerDay'] = df['cigsPerDay'].astype(int)
df['BPMeds'] = df['BPMeds'].astype(bool)
df['prevalentStroke'] = df['prevalentStroke'].astype(bool)
df['prevalentHyp'] = df['prevalentHyp'].astype(bool)
df['diabetes'] = df['diabetes'].astype(bool)
df['totChol'] = df['totChol'].astype(int)
df['sysBP'] = df['sysBP'].astype(int)
df['diaBP'] = df['diaBP'].astype(int)
df['heartRate'] = df['heartRate'].astype(int)
df['glucose'] = df['glucose'].astype(int)
df['TenYearCHD'] = df['TenYearCHD'].astype(bool)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4183 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4183 non-null   bool
#  1   age              4183 non-null   int64
#  2   education        4183 non-null   int32
#  3   currentSmoker    4183 non-null   bool
#  4   cigsPerDay       4183 non-null   int32
#  5   BPMeds           4183 non-null   bool
#  6   prevalentStroke  4183 non-null   bool
#  7   prevalentHyp     4183 non-null   bool
#  8   diabetes         4183 non-null   bool
#  9   totChol          4183 non-null   int32
#  10  sysBP            4183 non-null   int32
#  11  diaBP            4183 non-null   int32
#  12  BMI              4183 non-null   float64
#  13  heartRate        4183 non-null   int32
#  14  glucose          4183 non-null   int32
#  15  TenYearCHD       4183 non-null   bool
# dtypes: bool(7), float64(1), int32(7), int64(1)
# ...

# %% [markdown]
# ## Создаём Dummy-переменные на основе колонок

# %%
df_nums = df.select_dtypes(exclude='object')
df_objs = df.select_dtypes(include='object')

# %%
df_nums.head()
# Out:
#     male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0   True   39          4          False           0   False            False
# 1  False   46          2          False           0   False            False
# 2   True   48          1           True          20   False            False
# 3  False   61          3           True          30   False            False
# 4  False   46          3           True          23   False            False
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0         False     False      195    106     70  26.97         80       77
# 1         False     False      250    121     81  28.73         95       76
# 2         False     False      245    127     80  25.34         75       70
# 3          True     False      225    150     95  28.58         65      103
# 4         False     False      285    130     84  23.10         85       85
#
#    TenYearCHD
# 0       False
# 1       False
# ...

# %%
df_objs.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df.corr()['sysBP'].sort_values()
# Out:
# currentSmoker     -0.130819
# education         -0.123614
# cigsPerDay        -0.087453
# male              -0.031073
# prevalentStroke    0.055968
# diabetes           0.105498
# glucose            0.129387
# heartRate          0.180212
# TenYearCHD         0.209340
# totChol            0.212184
# BPMeds             0.224486
# BMI                0.326364
# age                0.394189
# prevalentHyp       0.700137
# diaBP              0.779764
# sysBP              1.000000
# Name: sysBP, dtype: float64

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot: >
